# %%
pip install --upgrade matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 1.1 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.1 MB 1.7 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.4/8.1 MB 2.2 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.1 MB 2.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.1 MB 3.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.1 MB 3.5 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

# %%
url = "https://web.stanford.edu/class/cs109/lectures/2014/lecture8/titanic.csv"  # You can replace this with your local file path
titanic_data = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 url = "https://web.stanford.edu/class/cs109/lectures/2014/lecture8/titanic.csv"  # You can replace this with your local file path
# ----> 2 titanic_data = pd.read_csv(url)
#
# ...

# %%
# Preprocess the data (fill missing values, encode categorical columns, etc.)
# For simplicity, we are focusing on Age, Pclass, and Sex columns
titanic_data = titanic_data[['Pclass', 'Sex', 'Age', 'Survived']]

# Drop rows with missing values for simplicity
titanic_data = titanic_data.dropna()
